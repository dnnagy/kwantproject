# %% [markdown]
# # Transport through a barrier
#
# All systems so far had a flat potential.  In this notebook, we will change this.
#
# Basic setup (like in the previous notebook):

# %%
import numpy as np
import kwant
# %run matplotlib_setup.ipy
from matplotlib import pyplot

# %%
lat = kwant.lattice.square()

# %% [markdown]
# ## "MOSFET" toy model
#
# Let's construct a system like the wire of the previous notebook, except that the scattering region will have a higher (but still flat) potential.
#
# The leads are unchanged, so we take the following function directly from the previous notebook.

# %%
def make_lead_x(W=10, t=1):
    syst = kwant.Builder(kwant.TranslationalSymmetry([-1, 0]))
    syst[(lat(0, y) for y in range(W))] = 4 * t
    syst[lat.neighbors()] = -t
    return syst

# %% [markdown]
# The next one is slightly modified: the onsite value is now no longer a constant but a *value function*.
#
# Kwant’s value functions are used when there are parameters to the Hamiltonian.  Kwant will call them only when a calculation is requested, at the last possible moment.  The `onsite` function always take one arguments (the site), and an arbitrary number of parameters that are supplied by the user.  Here, there is only one such parameter: `V`.

# %%
def make_wire_with_flat_potential(W=10, L=2, t=1):
    def onsite(s, V):
        return (4 - V) * t

    # Construct the scattering region.
    sr = kwant.Builder()
    sr[(lat(x, y) for x in range(L) for y in range(W))] = onsite
    sr[lat.neighbors()] = -t

    # Build and attach lead from both sides.
    lead = make_lead_x(W, t)
    sr.attach_lead(lead)
    sr.attach_lead(lead.reversed())

    return sr

# %% [markdown]
# The following function also needs to be modified slightly: instead of plotting transmission as a function of energy, it plots transmission as the function of the Hamiltonian parameter, for a fixed energy.
#
# Observe how `args=[param]` is used to pass the user-specified Hamiltonian parameters to `kwant.smatrix`.  `args` must be a sequence of parameters, even if it's only a single one in this case.

# %%
def plot_transmission(syst, energy, params):
    # Compute conductance
    trans = []
    for param in params:
        smatrix = kwant.smatrix(syst, energy, args=[param])
        trans.append(smatrix.transmission(1, 0))
    
    pyplot.xlabel="V"
    pyplot.ylabel="t"
    pyplot.plot(params, trans)

# %% [markdown]
# Let's put the above functions to some use:

# %%
_syst = make_wire_with_flat_potential()
kwant.plot(_syst)
_syst = _syst.finalized()
kwant.plotter.bands(_syst.leads[0])
plot_transmission(_syst, 1, params=np.linspace(-2, 0, 51))
# Out:
# /Users/nagydaniel/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   """
# /Users/nagydaniel/miniconda3/lib/python3.6/site-packages/kwant/solvers/common.py:164: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   params=params)[:2]
# /Users/nagydaniel/miniconda3/lib/python3.6/site-packages/kwant/solvers/common.py:191: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   prop, stab = lead.modes(energy, args, params=params)
# /Users/nagydaniel/miniconda3/lib/python3.6/site-packages/kwant/system.py:305: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   ham = self.cell_hamiltonian(args, params=params)
# /Users/nagydaniel/miniconda3/lib/python3.6/site-packages/kwant/system.py:274: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   sparse=sparse, params=params)
# /Users/nagydaniel/miniconda3/lib/python3.6/site-packages/kwant/system.py:306: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   hop = self.inter_cell_hopping(args, params=params)
# /Users/nagydaniel/miniconda3/lib/python3.6/site-packages/kwant/system.py:286: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   sparse=sparse, params=params)
# /Users/nagydaniel/miniconda3/lib/python3.6/site-packages/kwant/system.py:307: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   symmetries = self.discrete_symmetry(args, params=params)

# %% [markdown]
# #### Your turn!
# Play with the parameters (width of the barrier, voltage range, etc.) and see how this affects the results.

# %% [markdown]
# ## Quantum point contact
#
# What will happen if we open a hole in the potential barrier?  This time we will try to use a more realistic potential.
#
# The following cell defines the potential that we are going to use.

# %%
from math import atan2, pi, sqrt

def rectangular_gate_pot(distance, left, right, bottom, top):
    """Compute the potential of a rectangular gate.
    
    The gate hovers at the given distance over the plane where the
    potential is evaluated.
    
    Based on J. Appl. Phys. 77, 4504 (1995)
    http://dx.doi.org/10.1063/1.359446
    """
    d, l, r, b, t = distance, left, right, bottom, top

    def g(u, v):
        return atan2(u * v, d * sqrt(u**2 + v**2 + d**2)) / (2 * pi)

    def func(x, y, voltage):
        return voltage * (g(x-l, y-b) + g(x-l, t-y) +
                          g(r-x, y-b) + g(r-x, t-y))

    return func

_gate1 = rectangular_gate_pot(10, 20, 50, -50, 15)
_gate2 = rectangular_gate_pot(10, 20, 50, 25, 90)

def qpc_potential(site, V):
    x, y = site.pos
    return _gate1(x, y, V) + _gate2(x, y, V)

# %% [markdown]
# The function below is almost like `make_wire_with_flat_potential`.  The difference is that it can be tuned to use a general potential using its first parameter.

# %%
def make_barrier(pot, W=40, L=70, t=1):
    def onsite(args):
        return 4 * t - pot(args)

    # Construct the scattering region.
    sr = kwant.Builder()
    sr[(lat(x, y) for x in range(L) for y in range(W))] = onsite
    sr[lat.neighbors()] = -t

    # Build and attach lead from both sides.
    lead = make_lead_x(W, t)
    sr.attach_lead(lead)
    sr.attach_lead(lead.reversed())

    return sr

# %% [markdown]
# Let's construct the system and plot the potential.  The lambda expression is used to fix the gate voltage to a particular value.

# %%
qpc = make_barrier(qpc_potential)
kwant.plot(qpc);
kwant.plotter.map(qpc, lambda s: qpc_potential(s, 1));

# %% [markdown]
# To get an idea of the involved energy scales it's useful to plot the band structure:

# %%
fqpc = qpc.finalized()
kwant.plotter.bands(fqpc.leads[0]);

# %% [markdown]
# Finally, let's plot transmission as a function of the gate voltage.  We see the hallmark of the QPC: conductance quantization.  It's similar to what we saw in the clean wire, but now much more "realistic".

# %%
plot_transmission(fqpc, 0.3, params=np.linspace(1, 100, 100))
# Out:
# /Users/nagydaniel/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: KwantDeprecationWarning: The 'args' parameter has been deprecated since version 1.4 -- Instead, provide named parameters as a dictionary via 'params'.
#   """
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/kwant/builder.py in hamiltonian(self, i, j, params, *args)
#    1864                 try:
# -> 1865                     value = value(site, *args)
#    1866                 except Exception as exc:
#
# TypeError: onsite() takes 1 positional argument but 2 were given
#
# The above exception was the direct cause of the following exception:
#
# UserCodeError                             Traceback (most recent call last)
# <ipython-input-26-24786a2f858b> in <module>
# ----> 1 plot_transmission(fqpc, 0.3, params=np.linspace(1, 100, 100))
#
# <ipython-input-16-108642eec17f> in plot_transmission(syst, energy, params)
#       3     trans = []
#       4     for param in params:
# ----> 5         smatrix = kwant.smatrix(syst, energy, args=[param])
#       6         trans.append(smatrix.transmission(1, 0))
#       7
#
# ~/miniconda3/lib/python3.6/site-packages/kwant/_common.py in inner(*args, **kwargs)
#      70             if sig.bind(*args, **kwargs).arguments.get(parameter_name):
#      71                 warn()
# ---> 72             return f(*args, **kwargs)
#      73
#      74         return inner
#
# ~/miniconda3/lib/python3.6/site-packages/kwant/solvers/common.py in smatrix(self, sys, energy, args, out_leads, in_leads, check_hermiticity, params)
#     371         linsys, lead_info = self._make_linear_sys(syst, in_leads, energy, args,
#     372                                                   check_hermiticity, False,
# --> 373                                                   params=params)
#     374
#     375         kept_vars = np.concatenate([coords for i, coords in
#
# ~/miniconda3/lib/python3.6/site-packages/kwant/solvers/common.py in _make_linear_sys(self, sys, in_leads, energy, args, check_hermiticity, realspace, params)
#     162         lhs, norb = syst.hamiltonian_submatrix(args, sparse=True,
#     163                                                return_norb=True,
# --> 164                                                params=params)[:2]
#     165         lhs = getattr(lhs, 'to' + self.lhsformat)()
#     166         lhs = lhs - energy * sp.identity(lhs.shape[0], format=self.lhsformat)
#
# ~/miniconda3/lib/python3.6/site-packages/kwant/_common.py in inner(*args, **kwargs)
#      70             if sig.bind(*args, **kwargs).arguments.get(parameter_name):
#      71                 warn()
# ---> 72             return f(*args, **kwargs)
#      73
#      74         return inner
#
# kwant/_system.pyx in kwant._system.hamiltonian_submatrix()
#
# ~/miniconda3/lib/python3.6/site-packages/kwant/builder.py in hamiltonian(self, i, j, params, *args)
#    1871                                    ', '.join(map('"{}"'.format, missing)))
#    1872                             raise TypeError(''.join(msg))
# -> 1873                     _raise_user_error(exc, value)
#    1874         else:
#    1875             edge_id = self.graph.first_edge_id(i, j)
#
# ~/miniconda3/lib/python3.6/site-packages/kwant/builder.py in _raise_user_error(exc, func)
#    1796     msg = ('Error occurred in user-supplied value function "{0}".\n'
#    1797            'See the upper part of the above backtrace for more information.')
# -> 1798     raise UserCodeError(msg.format(func.__name__)) from exc
#    1799
#    1800
#
# UserCodeError: Error occurred in user-supplied value function "onsite".
# See the upper part of the above backtrace for more information.

# %% [markdown]
# #### Your turn!
# Play with the parameters?  For example, what happens if you make the QPC potential "shorter"?
